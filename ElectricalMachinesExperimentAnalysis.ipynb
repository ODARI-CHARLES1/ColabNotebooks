# %% [markdown]
# <a href="https://colab.research.google.com/github/ODARI-CHARLES1/ColabNotebooks/blob/main/ElectricalMachinesExperimentAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import files
file=files.upload()
# Out:
#      <input type="file" id="files-8aff2351-4097-4a9d-8cfb-e079e0fdfd4d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8aff2351-4097-4a9d-8cfb-e079e0fdfd4d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df_oc=pd.read_excel('/content/openCharacteristicsData.xlsx')
df_op=pd.read_excel('/content/External&InternalCharData.xlsx')

# %%
df_op.head()
# Out:
#    Load Current   Vt  Ia_Ra  vt_IL
# 0           0.0  250    NaN    NaN
# 1           0.4  243    NaN    NaN
# 2           0.6  239    NaN    NaN
# 3           0.7  236    NaN    NaN
# 4           1.1  228    NaN    NaN

# %%
df_op['Ia_Ra']=df_op['Load Current']*10
df_op['vt_IL']=df_op['Vt']+df_op['Ia_Ra']

# %%
df_op.head()
# Out:
#    Load Current   Vt  Ia_Ra  vt_IL
# 0           0.0  250    0.0  250.0
# 1           0.4  243    4.0  247.0
# 2           0.6  239    6.0  245.0
# 3           0.7  236    7.0  243.0
# 4           1.1  228   11.0  239.0

# %%
df_oc.head()
# Out:
#    Field Current  Induced EMF
# 0           0.00           10
# 1           0.02           68
# 2           0.04          119
# 3           0.06          163
# 4           0.08          200

# %%
plt.title("Induced EMF against Field Current1")
plt.xlabel("Field Current")
plt.ylabel("Induced EMF")
plt.plot(df_oc['Field Current'],df_oc['Induced EMF'])
plt.grid(True)

# %%
df_op
df_op['Vt'][7]=215
# Out:
# /tmp/ipython-input-40-4218073386.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_op['Vt'][7]=215

# %%
plt.title("Terminal Voltage gainst Load Current")
plt.xlabel("Field Current")
plt.ylabel("Induced EMF")
plt.plot(df_op['Load Current'],df_op['Vt'])
plt.grid(True)

# %%
df_op.head()
# Out:
#    Load Current   Vt  Ia_Ra  vt_IL
# 0           0.0  250    0.0  250.0
# 1           0.4  243    4.0  247.0
# 2           0.6  239    6.0  245.0
# 3           0.7  236    7.0  243.0
# 4           1.1  228   11.0  239.0

# %%
plt.title("Performance Curve for External and Internal Characteristics")
plt.xlabel("Field Current")
plt.ylabel("Induced EMF")
plt.plot(df_op['vt_IL'],df_op['Ia_Ra'])
plt.grid(True)
